# %% [markdown]
# <a href="https://colab.research.google.com/github/tommydb26/datasci112-playlist-generator/blob/main/Final_Project_Data_Collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gaining Access to the API

# %% [markdown]
# Spotify's API requires that a user get authorization with OAuth, which requires that they disclose their app to spotify in order to retrieve a client_id and client_secret. Further, you have to specify the scope of endpoints which you will be using. By doing this you can recieve an access token, which must then be provided as a header to all of your requests, so I saved that in a variable.

# %%
import requests
import time
import pandas as pd

# %%
BASE_URL = 'https://api.spotify.com/v1/'

# %%
client_id = "92268fea8a0347819b9704544dfa2191"
scope = "user-top-read user-library-read playlist-read-collaborative"

client_secret = "1b4c3b1dee5740b19ac0a90d2084fefd"

# %%
AUTH_URL = 'https://accounts.spotify.com/api/token'

auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': client_id,
    'client_secret': client_secret,
    "scope": scope
})

access_token = auth_response.json()["access_token"]
access_token
# Out:
# 'BQANnGemylq8qvUHQ5CbBg4SOefkFhztTUkZALK0KMtgrZCqPu_Miy4KkT88sSIjyi-_Snkc591bhdVe28ERPl3MBYU01Jd_4mOE56lPPzWANoZHOnN3rNAbouahg6SiFRZN3DsEZg'

# %%
headers = {
    'Authorization': f'Bearer {access_token}'
}

# %% [markdown]
# # Collecting All Liked Songs

# %% [markdown]
# For the basis of my playlists, I decided to use my liked songs on Spotify. I am such an ardent user of this feature — if there's a song I am even remotely interested in, I like it. So, I figured this would be a good pool to pull from for my playlists.

# %% [markdown]
# Spotify only allows you to access 50 tracks at a time from a collection of songs. So, I created a DataFrame for the first 50 tracks, then I repeatedly concatenated to it a DataFrame of the next 50. In the first request, I included in the fields the total number of tracks in the playlist, which I would use to control the iteration.

# %%
response = requests.get(f"{BASE_URL}playlists/2uvsRnwp5NdXJGnFzkaFbS/tracks?fields=total%2C%20items(track(artists.name%2C%20popularity%2C%20explicit%2C%20id%2C%20name))&limit=50&offset=0",
                        headers=headers)

data = response.json()
total = data["total"]
data
# Out:
# {'items': [{'track': {'artists': [{'name': 'Miley Cyrus'}],
#     'explicit': False,
#     'id': '6FAsJDkg4y5JSWP9ZMKlDj',
#     'name': 'You',
#     'popularity': 77}},
#   {'track': {'artists': [{'name': 'Charles Givings'}],
#     'explicit': False,
#     'id': '5lnLxpRxCDlqedyWgkBLOh',
#     'name': 'Easy (LIke Sunday Morning)',
#     'popularity': 47}},
#   {'track': {'artists': [{'name': 'Bread'}],
#     'explicit': False,
#     'id': '7IX2e7pEShera9T1QIMvi7',
#     'name': "Baby I'm-a Want You",
#     'popularity': 64}},
#   {'track': {'artists': [{'name': 'Bread'}],
#     'explicit': False,
#     'id': '52VIdyKqp1pJRSyUQaxKUA',
#     'name': 'Everything I Own',
#     'popularity': 70}},
#   {'track': {'artists': [{'name': 'Cigarettes After Sex'}],
#     'explicit': False,
#     'id': '3AVrVz5rK8Hrqo9YGiVGN5',
#     'name': 'Apocalypse',
#     'popularity': 81}},
#   {'track': {'artists': [{'name': 'Maggie Rogers'}],
#     'explicit': False,
#     'id': '3rST7c7KrUNLAmWGb8ZKUI',
#     'name': 'Alaska - Acoustic',
#     'popularity': 41}},
#   {'track': {'artists': [{'name': 'The Dip'}],
#     'explicit': False,
#     'id': '0lEWIegMNMQ7W1ooB1zWT2',
#     'name': "Sure Don't Miss You",
#     'popularity': 59}},
#   {'track': {'artists': [{'name': 'Eloise'}],
#     'explicit': False,
#     'id': '3yAlkOEMjk2rH2hZTgvfoH',
#     'name': 'Left Side',
#     'popularity': 55}},
#   {'track': {'artists': [{'name': 'Paul Simon'}],
#     'explicit': False,
#     'id': '2qQrVJQ7zXAyvqX1IkwsS2',
#     'name': 'Take Me to the Mardi Gras',
#     'popularity': 38}},
#   {'track': {'artists': [{'name': 'Beyoncé'}],
#     'explicit': True,
#     'id': '4DByEumlGTZKSzuVEZ35eo',
#     'name': 'PURE/HONEY',
#     'popularity': 70}},
#   {'track': {'artists': [{'name': 'John Mayer'}],
#     'explicit': False,
#     'id': '3E6iea9uEmB7gRru4lyP6h',
#     'name': 'Stop This Train',
#     'popularity': 63}},
#   {'track': {'artists': [{'name': 'Suki Waterhouse'}],
#     'explicit': False,
#     'id': '6TT7B4MigCJCc0tqKYEpZC',
#     'name': 'Moves',
#     'popularity': 63}},
#   {'track': {'artists': [{'name': 'Reneé Rapp'}],
#     'explicit': True,
#     'id': '5kUqU9uLc98ndpJiqieN8K',
#     'name': 'Bruises',
#     'popularity': 70}},
#   {'track': {'artists': [{'name': 'Beyoncé'}],
#     'explicit': True,
#     'id': '2XMAWynSTIst5KmLSv0Npf',
#     'name': 'AMERICA HAS A PROBLEM',
#     'popularity': 78}},
#   {'track': {'artists': [{'name': 'EASHA'}],
#     'explicit': False,
#     'id': '0Y4xg5612xZ3vAgWEkMjw3',
#     'name': 'Far Away',
#     'popularity': 52}},
#   {'track': {'artists': [{'name': 'Yebba'}],
#     'explicit': False,
#     'id': '4UuwnKoOKWYYnerZKZMtvD',
#     'name': 'Evergreen',
#     'popularity': 55}},
#   {'track': {'artists': [{'name': 'Steve Lacy'}],
#     'explicit': False,
#     'id': '7a60lyI9Wy3eezBpGZ37Ni',
#     'name': 'Lay Me Down',
#     'popularity': 57}},
#   {'track': {'artists': [{'name': 'Steve Lacy'}],
#     'explicit': False,
#     'id': '7wNAM0qzErN5Dr9uV6B3fW',
#     'name': 'Only If',
#     'popularity': 64}},
#   {'track': {'artists': [{'name': 'Corinne Bailey Rae'}],
#     'explicit': False,
#     'id': '7aFQa52bLiHwb3BXPbmKdZ',
#     'name': 'Like A Star',
#     'popularity': 34}},
#   {'track': {'artists': [{'name': 'Amy Winehouse'}],
#     'explicit': False,
#     'id': '4VbqUDBWyK15pTal9THtFu',
#     'name': '(There Is) No Greater Love',
#     'popularity': 44}},
#   {'track': {'artists': [{'name': 'Pink Floyd'}],
#     'explicit': False,
#     'id': '2ctvdKmETyOzPb2GiJJT53',
#     'name': 'Breathe (In the Air)',
#     'popularity': 72}},
#   {'track': {'artists': [{'name': 'Tame Impala'}],
#     'explicit': True,
#     'id': '0xtIp0lgccN85GfGOekS5L',
#     'name': "Yes I'm Changing",
#     'popularity': 68}},
#   {'track': {'artists': [{'name': 'Steely Dan'}],
#     'explicit': False,
#     'id': '7GVvj4zJNVuBJSl6StEfn5',
#     'name': 'Only A Fool Would Say That',
#     'popularity': 60}},
#   {'track': {'artists': [{'name': 'The Smashing Pumpkins'}],
#     'explicit': False,
#     'id': '5Q6Xzp25aXYxNJ4B6vBkcf',
#     'name': 'Luna - 2011 Remaster',
#     'popularity': 58}},
#   {'track': {'artists': [{'name': 'Bruno Mars'}],
#     'explicit': False,
#     'id': '0kN8xEmgMW9mh7UmDYHlJP',
#     'name': 'Versace on the Floor',
#     'popularity': 74}},
#   {'track': {'artists': [{'name': 'Thee Sacred Souls'}],
#     'explicit': False,
#     'id': '0gzDu0smnvgwslqwOiQ8f1',
#     'name': 'Will I See You Again?',
#     'popularity': 61}},
#   {'track': {'artists': [{'name': 'George Harrison'}],
#     'explicit': False,
#     'id': '5zUP3RRw1vmZAsswtE3GrP',
#     'name': 'If Not for You - 2014 Remaster',
#     'popularity': 57}},
#   {'track': {'artists': [{'name': 'Simon & Garfunkel'}],
#     'explicit': False,
#     'id': '6dfhF1BDGmhM69fnCb6wSC',
#     'name': 'America',
#     'popularity': 62}},
#   {'track': {'artists': [{'name': 'Crosby, Stills & Nash'}],
#     'explicit': False,
#     'id': '4dAN7KcWCWx5jV6dpwtfvN',
#     'name': 'Just a Song Before I Go',
#     'popularity': 62}},
#   {'track': {'artists': [{'name': 'Pink Floyd'}],
#     'explicit': False,
#     'id': '2TjdnqlpwOjhijHCwHCP2d',
#     'name': 'The Great Gig in the Sky',
#     'popularity': 75}},
#   {'track': {'artists': [{'name': 'Corinne Bailey Rae'}],
#     'explicit': False,
#     'id': '7m8PDR3PRg5lPhWMdYrktc',
#     'name': 'Trouble Sleeping',
#     'popularity': 54}},
#   {'track': {'artists': [{'name': 'boygenius'},
#      {'name': 'Julien Baker'},
#      {'name': 'Phoebe Bridgers'},
#      {'name': 'Lucy Dacus'}],
#     'explicit': False,
#     'id': '72GNW1xKoi5BAhMYAW6e7e',
#     'name': 'Not Strong Enough',
#     'popularity': 70}},
#   {'track': {'artists': [{'name': 'Lake Street Dive'}],
#     'explicit': False,
#     'id': '3sXYULhZaeZSjScbf2E0KJ',
#     'name': 'Linger',
#     'popularity': 44}},
#   {'track': {'artists': [{'name': 'Pink Floyd'}],
#     'explicit': False,
#     'id': '1mLSXiRGgDqjkMJ8tskhVg',
#     'name': 'Biding My Time',
#     'popularity': 28}},
#   {'track': {'artists': [{'name': 'Pink Floyd'}],
#     'explicit': False,
#     'id': '1TKTiKp3zbNgrBH2IwSwIx',
#     'name': 'Us and Them',
#     'popularity': 66}},
#   {'track': {'artists': [{'name': 'MATVEÏ'}, {'name': 'warner case'}],
#     'explicit': False,
#     'id': '3U7ZzaQjslHlHybw9jXQI8',
#     'name': 'REGRESO - warner case Remix',
#     'popularity': 47}},
#   {'track': {'artists': [{'name': 'Jim Croce'}],
#     'explicit': False,
#     'id': '4t8tx6o7oM6Ax66ZUU361y',
#     'name': "I'll Have To Say I Love You In A Song",
#     'popularity': 65}},
#   {'track': {'artists': [{'name': 'Irma Thomas'}],
#     'explicit': False,
#     'id': '6939d7AvgMNTBS7tiqsdHW',
#     'name': "It's Raining",
#     'popularity': 52}},
#   {'track': {'artists': [{'name': 'James Taylor'}],
#     'explicit': False,
#     'id': '75Nlnd9AJ4CYrLXgWGsuTF',
#     'name': 'How Sweet It Is (To Be Loved By You) - 2019 Remaster',
#     'popularity': 63}},
#   {'track': {'artists': [{'name': 'Carpenters'}],
#     'explicit': False,
#     'id': '6q2TZbqEnDh5elzJlQEWwv',
#     'name': 'A Song For You',
#     'popularity': 52}},
#   {'track': {'artists': [{'name': 'Carpenters'}],
#     'explicit': False,
#     'id': '4ntGcAWEyS9f50DToHTfWW',
#     'name': "I'll Never Fall In Love Again",
#     'popularity': 32}},
#   {'track': {'artists': [{'name': 'Carpenters'}],
#     'explicit': False,
#     'id': '6Gqb3fskMAjy90VmIe0nVG',
#     'name': "Maybe It's You",
#     'popularity': 33}},
#   {'track': {'artists': [{'name': 'The Mamas & The Papas'}],
#     'explicit': False,
#     'id': '46RVIZHY0PgIHT4Wbj1Swr',
#     'name': 'I Call Your Name',
#     'popularity': 46}},
#   {'track': {'artists': [{'name': 'ella jane'}],
#     'explicit': False,
#     'id': '1IXfNzFG3JdrjBt8VPDjC6',
#     'name': 'I Wanna',
#     'popularity': 39}},
#   {'track': {'artists': [{'name': 'Laufey'}],
#     'explicit': False,
#     'id': '1hUXDEqjNIIbfjTcaz3jzb',
#     'name': 'Like the Movies',
#     'popularity': 64}},
#   {'track': {'artists': [{'name': 'Laufey'}],
#     'explicit': False,
#     'id': '4KLZOU5V5XuEkvytSgyW6u',
#     'name': 'Slow Down',
#     'popularity': 55}},
#   {'track': {'artists': [{'name': 'PHOX'}],
#     'explicit': False,
#     'id': '2nC7tenySg74WS6ATykrd8',
#     'name': 'Noble Heart',
#     'popularity': 28}},
#   {'track': {'artists': [{'name': 'Loggins & Messina'}],
#     'explicit': False,
#     'id': '0ju1jP0cSPJ8tmojYBEI89',
#     'name': "Danny's Song",
#     'popularity': 62}},
#   {'track': {'artists': [{'name': 'James Taylor'}],
#     'explicit': False,
#     'id': '2T5Ch09nefwckOu5NQvjIk',
#     'name': 'Carolina in My Mind',
#     'popularity': 64}},
#   {'track': {'artists': [{'name': 'Van Morrison'}],
#     'explicit': False,
#     'id': '6KHNMPZTSif1zFbFKErpNU',
#     'name': 'Moondance - 2013 Remaster',
#     'popularity': 48}}],
#  'total': 1493}

# %%
df_songs = pd.json_normalize(data["items"])
df_songs
# Out:
#                                         track.artists  track.explicit  \
# 0                           [{'name': 'Miley Cyrus'}]           False
# 1                       [{'name': 'Charles Givings'}]           False
# 2                                 [{'name': 'Bread'}]           False
# 3                                 [{'name': 'Bread'}]           False
# 4                  [{'name': 'Cigarettes After Sex'}]           False
# 5                         [{'name': 'Maggie Rogers'}]           False
# 6                               [{'name': 'The Dip'}]           False
# 7                                [{'name': 'Eloise'}]           False
# 8                            [{'name': 'Paul Simon'}]           False
# 9                               [{'name': 'Beyoncé'}]            True
# 10                           [{'name': 'John Mayer'}]           False
# 11                      [{'name': 'Suki Waterhouse'}]           False
# 12                           [{'name': 'Reneé Rapp'}]            True
# 13                              [{'name': 'Beyoncé'}]            True
# 14                                [{'name': 'EASHA'}]           False
# 15                                [{'name': 'Yebba'}]           False
# 16                           [{'name': 'Steve Lacy'}]           False
# 17                           [{'name': 'Steve Lacy'}]           False
# 18                   [{'name': 'Corinne Bailey Rae'}]           False
# 19                        [{'name': 'Amy Winehouse'}]           False
# 20                           [{'name': 'Pink Floyd'}]           False
# 21                          [{'name': 'Tame Impala'}]            True
# 22                           [{'name': 'Steely Dan'}]           False
# 23                [{'name': 'The Smashing Pumpkins'}]           False
# 24                           [{'name': 'Bruno Mars'}]           False
# 25                    [{'name': 'Thee Sacred Souls'}]           False
# 26                      [{'name': 'George Harrison'}]           False
# 27                    [{'name': 'Simon & Garfunkel'}]           False
# 28                [{'name': 'Crosby, Stills & Nash'}]           False
# 29                           [{'name': 'Pink Floyd'}]           False
# 30                   [{'name': 'Corinne Bailey Rae'}]           False
# 31  [{'name': 'boygenius'}, {'name': 'Julien Baker...           False
# 32                     [{'name': 'Lake Street Dive'}]           False
# 33                           [{'name': 'Pink Floyd'}]           False
# 34                           [{'name': 'Pink Floyd'}]           False
# 35      [{'name': 'MATVEÏ'}, {'name': 'warner case'}]           False
# 36                            [{'name': 'Jim Croce'}]           False
# 37                          [{'name': 'Irma Thomas'}]           False
# 38                         [{'name': 'James Taylor'}]           False
# 39                           [{'name': 'Carpenters'}]           False
# 40                           [{'name': 'Carpenters'}]           False
# 41                           [{'name': 'Carpenters'}]           False
# 42                [{'name': 'The Mamas & The Papas'}]           False
# 43                            [{'name': 'ella jane'}]           False
# 44                               [{'name': 'Laufey'}]           False
# 45                               [{'name': 'Laufey'}]           False
# 46                                 [{'name': 'PHOX'}]           False
# 47                    [{'name': 'Loggins & Messina'}]           False
# 48                         [{'name': 'James Taylor'}]           False
# 49                         [{'name': 'Van Morrison'}]           False
#
#                   track.id                                         track.name  \
# 0   6FAsJDkg4y5JSWP9ZMKlDj                                                You
# 1   5lnLxpRxCDlqedyWgkBLOh                         Easy (LIke Sunday Morning)
# 2   7IX2e7pEShera9T1QIMvi7                                Baby I'm-a Want You
# 3   52VIdyKqp1pJRSyUQaxKUA                                   Everything I Own
# 4   3AVrVz5rK8Hrqo9YGiVGN5                                         Apocalypse
# 5   3rST7c7KrUNLAmWGb8ZKUI                                  Alaska - Acoustic
# 6   0lEWIegMNMQ7W1ooB1zWT2                                Sure Don't Miss You
# 7   3yAlkOEMjk2rH2hZTgvfoH                                          Left Side
# 8   2qQrVJQ7zXAyvqX1IkwsS2                          Take Me to the Mardi Gras
# 9   4DByEumlGTZKSzuVEZ35eo                                         PURE/HONEY
# 10  3E6iea9uEmB7gRru4lyP6h                                    Stop This Train
# 11  6TT7B4MigCJCc0tqKYEpZC                                              Moves
# 12  5kUqU9uLc98ndpJiqieN8K                                            Bruises
# 13  2XMAWynSTIst5KmLSv0Npf                              AMERICA HAS A PROBLEM
# 14  0Y4xg5612xZ3vAgWEkMjw3                                           Far Away
# 15  4UuwnKoOKWYYnerZKZMtvD                                          Evergreen
# 16  7a60lyI9Wy3eezBpGZ37Ni                                        Lay Me Down
# 17  7wNAM0qzErN5Dr9uV6B3fW                                            Only If
# 18  7aFQa52bLiHwb3BXPbmKdZ                                        Like A Star
# 19  4VbqUDBWyK15pTal9THtFu                         (There Is) No Greater Love
# 20  2ctvdKmETyOzPb2GiJJT53                               Breathe (In the Air)
# 21  0xtIp0lgccN85GfGOekS5L                                   Yes I'm Changing
# 22  7GVvj4zJNVuBJSl6StEfn5                         Only A Fool Would Say That
# 23  5Q6Xzp25aXYxNJ4B6vBkcf                               Luna - 2011 Remaster
# 24  0kN8xEmgMW9mh7UmDYHlJP                               Versace on the Floor
# 25  0gzDu0smnvgwslqwOiQ8f1                              Will I See You Again?
# 26  5zUP3RRw1vmZAsswtE3GrP                     If Not for You - 2014 Remaster
# 27  6dfhF1BDGmhM69fnCb6wSC                                            America
# 28  4dAN7KcWCWx5jV6dpwtfvN                            Just a Song Before I Go
# 29  2TjdnqlpwOjhijHCwHCP2d                           The Great Gig in the Sky
# 30  7m8PDR3PRg5lPhWMdYrktc                                   Trouble Sleeping
# 31  72GNW1xKoi5BAhMYAW6e7e                                  Not Strong Enough
# 32  3sXYULhZaeZSjScbf2E0KJ                                             Linger
# 33  1mLSXiRGgDqjkMJ8tskhVg                                     Biding My Time
# 34  1TKTiKp3zbNgrBH2IwSwIx                                        Us and Them
# 35  3U7ZzaQjslHlHybw9jXQI8                        REGRESO - warner case Remix
# 36  4t8tx6o7oM6Ax66ZUU361y              I'll Have To Say I Love You In A Song
# 37  6939d7AvgMNTBS7tiqsdHW                                       It's Raining
# 38  75Nlnd9AJ4CYrLXgWGsuTF  How Sweet It Is (To Be Loved By You) - 2019 Re...
# 39  6q2TZbqEnDh5elzJlQEWwv                                     A Song For You
# 40  4ntGcAWEyS9f50DToHTfWW                      I'll Never Fall In Love Again
# 41  6Gqb3fskMAjy90VmIe0nVG                                     Maybe It's You
# 42  46RVIZHY0PgIHT4Wbj1Swr                                   I Call Your Name
# 43  1IXfNzFG3JdrjBt8VPDjC6                                            I Wanna
# 44  1hUXDEqjNIIbfjTcaz3jzb                                    Like the Movies
# 45  4KLZOU5V5XuEkvytSgyW6u                                          Slow Down
# 46  2nC7tenySg74WS6ATykrd8                                        Noble Heart
# 47  0ju1jP0cSPJ8tmojYBEI89                                       Danny's Song
# 48  2T5Ch09nefwckOu5NQvjIk                                Carolina in My Mind
# 49  6KHNMPZTSif1zFbFKErpNU                          Moondance - 2013 Remaster
#
#     track.popularity
# 0                 77
# 1                 47
# 2                 64
# 3                 70
# 4                 81
# 5                 41
# 6                 59
# 7                 55
# 8                 38
# 9                 70
# 10                63
# 11                63
# 12                70
# 13                78
# 14                52
# 15                55
# 16                57
# 17                64
# 18                34
# 19                44
# 20                72
# 21                68
# 22                60
# 23                58
# 24                74
# 25                61
# 26                57
# 27                62
# 28                62
# 29                75
# 30                54
# 31                70
# 32                44
# 33                28
# 34                66
# 35                47
# 36                65
# 37                52
# 38                63
# 39                52
# 40                32
# 41                33
# 42                46
# 43                39
# 44                64
# 45                55
# 46                28
# 47                62
# 48                64
# 49                48

# %%
offset = 50
while offset <= total:
  response = requests.get((f"""{BASE_URL}playlists/2uvsRnwp5NdXJGnFzkaFbS/tracks?fields=items(track(artists.name%2C%20popularity%2C%20explicit%2C%20id%2C%20name))&limit=50&offset={offset}"""),
                        headers=headers)
  new_data = response.json()
  df_songs = pd.concat([df_songs, pd.json_normalize(new_data["items"])])

  time.sleep(0.5)
  offset += 50

# %%
# save this for later, when we will need it for naming the columns of joined df
indices = df_songs["track.name"]

# %%
df_songs.set_index("track.name", inplace=True)

# %% [markdown]
# I then did some brief cleaning on the artists column; although I will not be training on this data, it will be important that it is readable for displaying playlists

# %%
s = df_songs["track.artists"].astype(str).str[1:-1]
s = s.str.replace("{'name': ", "", regex=True)
s = s.str.replace("}", "", regex=True)
df_songs["track.artists"] = s
df_songs
# Out:
#                                      track.artists  track.explicit  \
# track.name
# You                                  'Miley Cyrus'           False
# Easy (LIke Sunday Morning)       'Charles Givings'           False
# Baby I'm-a Want You                        'Bread'           False
# Everything I Own                           'Bread'           False
# Apocalypse                  'Cigarettes After Sex'           False
# ...                                            ...             ...
# Godspeed                             'Frank Ocean'           False
# Writer In The Dark                         'Lorde'           False
# Mood Ring                                  'Lorde'           False
# Bored                              'Billie Eilish'           False
# Hard Feelings/Loveless                     'Lorde'            True
#
#                                           track.id  track.popularity
# track.name
# You                         6FAsJDkg4y5JSWP9ZMKlDj                77
# Easy (LIke Sunday Morning)  5lnLxpRxCDlqedyWgkBLOh                47
# Baby I'm-a Want You         7IX2e7pEShera9T1QIMvi7                64
# Everything I Own            52VIdyKqp1pJRSyUQaxKUA                70
# Apocalypse                  3AVrVz5rK8Hrqo9YGiVGN5                81
# ...                                            ...               ...
# Godspeed                    34xTFwjPQ1dC6uJmleno7x                72
# Writer In The Dark          193Dm5SqYy3hTSbuzxbwKc                65
# Mood Ring                   6FE9EXi8TYg09hR4xv5PWJ                 0
# Bored                       04sN26COy28wTXYj3dMoiZ                81
# Hard Feelings/Loveless      1Dp7JGFNjvg8Nk0CtMCcnr                61
#
# [1493 rows x 4 columns]

# %% [markdown]
# Lastly, I just renamed the columns to simpler representations of the data.

# %%
df_songs.rename(mapper={
    "track.artists": "artists",
    "track.explicit": "explicit",
    "track.id": "id",
    "track.name": "name",
    "track.popularity": "popularity"
}, axis="columns", inplace=True)

# %% [markdown]
# I will be drawing from two main data sets that Spotify maintains — audio features and audio analysis.
#
# Audio features is much more surface level, and it includes objective traits like duration and loudness, but also some more subjective seeming ones like danceability or valence—which is the "positivity" of a song.
#
# Audio analysis is much more technical, and what I am interested in from it is the "timbre" vector. This takes timbre—the texture or color of a musical sound—and quantifies it as a vector of different qualities.

# %% [markdown]
# Even worse than extracting the songs from my liked songs, when collecting the data on each song the API can only process one song per request. So I begun by starting a dataframe for each endpoint with the first song. Then I looped through the rest of the songs, requesting from each endpoint and concatenating those to the respective data frames for each song.

# %%
track_id = df_songs.loc["You", "id"]

response = requests.get(f"{BASE_URL}audio-features/{track_id}", 
                        headers=headers)
df_features = pd.json_normalize(response.json())

# %%
track_id = df_songs.loc["You", "id"]
response = requests.get(f"{BASE_URL}audio-analysis/{track_id}", 
                        headers=headers)

# because I only wanted the timbre from the analysis, this data required some cleaning before I could manage it in a DataFrame
df_analysis = pd.json_normalize(response.json(), "segments")
df_timbres_throughout = pd.DataFrame(df_analysis["timbre"].to_list(), columns = range(1,13))
df_timbres = pd.DataFrame(df_timbres_throughout.mean()).transpose()

# I also had to manually re-add the track_id
df_timbres["id"] = track_id
df_timbres
# Out:
#            1         2          3          4          5          6         7  \
# 0  48.146507  6.755951  11.539323 -12.510097  23.383751 -16.174316  8.328809
#
#           8         9        10         11       12                      id
# 0 -2.556505 -4.282422 -3.378086 -10.891944  2.58411  6FAsJDkg4y5JSWP9ZMKlDj

# %%
for id in df_songs.iloc[1:, 2]:
  # add the audio features to the features df
  response = requests.get(f"{BASE_URL}audio-features/{id}", 
                        headers=headers)
  df_features = pd.concat([df_features, pd.json_normalize(response.json())])
  
  # rest to obey API principles
  time.sleep(0.25)

  # add the audio analysis to the timbres df
  response = requests.get(f"{BASE_URL}audio-analysis/{id}", 
                        headers=headers)
  df_analysis_ = pd.json_normalize(response.json(), "segments")
  df_timbres_throughout_ = pd.DataFrame(df_analysis_["timbre"].to_list(), columns = range(1,13))
  df_timbres_ = pd.DataFrame(df_timbres_throughout_.mean()).transpose()
  df_timbres_["id"] = id
  df_timbres = pd.concat([df_timbres, df_timbres_])

  # rest again
  time.sleep(0.25)

# %% [markdown]
# The cleaning for the features data came after; I figured it would be more efficient to do one drop of the unwanted rather than to drop them with every request.

# %%
df_features.drop(["type", "uri", "track_href", "analysis_url"], 
                 axis="columns", inplace=True)
df_features
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.625  0.5680   11    -5.663     1       0.0324        0.2880
# 0          0.584  0.4350   10   -11.736     0       0.0263        0.3010
# 0          0.613  0.2890    8   -16.529     1       0.0305        0.7430
# 0          0.365  0.3380    2   -13.406     1       0.0322        0.7350
# 0          0.369  0.4670    5    -9.018     1       0.0274        0.0194
# ..           ...     ...  ...       ...   ...          ...           ...
# 0          0.399  0.0969    6   -12.578     1       0.0509        0.9290
# 0          0.325  0.2710    7    -8.069     1       0.0418        0.7300
# 0          0.709  0.4590    5   -11.193     1       0.0654        0.4320
# 0          0.614  0.3180    7   -12.695     1       0.0478        0.8960
# 0          0.487  0.4450    1   -10.959     0       0.1130        0.0328
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.000000    0.6740   0.3480   85.545  6FAsJDkg4y5JSWP9ZMKlDj
# 0           0.007340    0.1260   0.3990  132.439  5lnLxpRxCDlqedyWgkBLOh
# 0           0.000002    0.0617   0.5530  144.188  7IX2e7pEShera9T1QIMvi7
# 0           0.000000    0.1040   0.4460   79.241  52VIdyKqp1pJRSyUQaxKUA
# 0           0.460000    0.1090   0.1740   94.473  3AVrVz5rK8Hrqo9YGiVGN5
# ..               ...       ...      ...      ...                     ...
# 0           0.000168    0.1210   0.0758  109.540  34xTFwjPQ1dC6uJmleno7x
# 0           0.000000    0.3010   0.2790   71.855  193Dm5SqYy3hTSbuzxbwKc
# 0           0.000006    0.2300   0.3770   95.014  6FE9EXi8TYg09hR4xv5PWJ
# 0           0.002390    0.0795   0.1120  119.959  04sN26COy28wTXYj3dMoiZ
# 0           0.010400    0.0778   0.1800   97.031  1Dp7JGFNjvg8Nk0CtMCcnr
#
#     duration_ms  time_signature
# 0        179427               3
# 0        266320               4
# 0        150707               4
# 0        187000               4
# 0        290147               4
# ..          ...             ...
# 0        177922               4
# 0        216611               4
# 0        225863               4
# 0        180933               4
# 0        367391               4
#
# [1493 rows x 14 columns]

# %%
df_timbres
# Out:
#             1          2          3          4          5          6  \
# 0   48.146507   6.755951  11.539323 -12.510097  23.383751 -16.174316
# 0   44.260628  19.184289  18.214885  -0.140513  24.040165 -24.511405
# 0   37.714839 -16.496544 -12.316468 -12.847976  25.861839 -19.737157
# 0   40.059674 -13.343394   2.044856  -5.262738  31.014177 -18.898640
# 0   47.540592 -12.982581 -16.650313 -22.373093  -1.733394 -29.764263
# ..        ...        ...        ...        ...        ...        ...
# 0   36.813218 -69.412050   5.840797 -22.330447  25.515002 -17.792400
# 0   46.052878   3.880775  20.611754  -9.098635  29.450032 -13.189979
# 0   41.471024   1.550384 -33.694737 -19.618376  30.164256 -24.133622
# 0   40.009522 -68.123945 -38.775284 -26.824530  42.881618 -28.542628
# 0   40.337009  -3.609758 -37.462178 -12.856534  14.994031 -25.034692
#
#             7         8          9        10         11        12  \
# 0    8.328809 -2.556505  -4.282422 -3.378086 -10.891944  2.584110
# 0   -3.840630 -6.885928  -2.012070 -1.377134  -7.607562  1.503317
# 0  -10.335721 -1.827133  -7.192570 -1.878703  -7.335082 -1.149978
# 0  -13.315408 -2.899277  -7.657300 -0.368305  -6.512232 -6.191590
# 0    7.681281 -1.659771  -2.585452 -2.547789  -8.395570 -1.803018
# ..        ...       ...        ...       ...        ...       ...
# 0  -15.280099  1.405760  -9.261899 -9.622248  -5.609669  2.967544
# 0  -17.050438 -2.646305 -14.314003 -4.656721 -10.477538 -4.439217
# 0  -19.055563 -6.317596  -6.653428 -2.188997  -8.915563 -1.431539
# 0  -12.061354 -0.955191  -2.552814 -1.145596  -9.702547  3.082146
# 0   -2.974385  6.429797  -1.796132  0.191998 -12.925284 -6.119865
#
#                         id
# 0   6FAsJDkg4y5JSWP9ZMKlDj
# 0   5lnLxpRxCDlqedyWgkBLOh
# 0   7IX2e7pEShera9T1QIMvi7
# 0   52VIdyKqp1pJRSyUQaxKUA
# 0   3AVrVz5rK8Hrqo9YGiVGN5
# ..                     ...
# 0   34xTFwjPQ1dC6uJmleno7x
# 0   193Dm5SqYy3hTSbuzxbwKc
# 0   6FE9EXi8TYg09hR4xv5PWJ
# 0   04sN26COy28wTXYj3dMoiZ
# 0   1Dp7JGFNjvg8Nk0CtMCcnr
#
# [1493 rows x 13 columns]

# %% [markdown]
# Spotify uniquely identifies songs by something called a track_id, which made it very easy to join my three DataFrames into one with id as a primary key in all of them. The default inner merge was sufficient since all three DataFrames have the same 1493 keys.

# %%
df_tracks_intermediate = df_songs.merge(df_features, on="id")
df_tracks = df_tracks_intermediate.merge(df_timbres, on="id")
df_tracks
# Out:
#                      artists  explicit                      id  popularity  \
# 0              'Miley Cyrus'     False  6FAsJDkg4y5JSWP9ZMKlDj          77
# 1          'Charles Givings'     False  5lnLxpRxCDlqedyWgkBLOh          47
# 2                    'Bread'     False  7IX2e7pEShera9T1QIMvi7          64
# 3                    'Bread'     False  52VIdyKqp1pJRSyUQaxKUA          70
# 4     'Cigarettes After Sex'     False  3AVrVz5rK8Hrqo9YGiVGN5          81
# ...                      ...       ...                     ...         ...
# 1488           'Frank Ocean'     False  34xTFwjPQ1dC6uJmleno7x          72
# 1489                 'Lorde'     False  193Dm5SqYy3hTSbuzxbwKc          65
# 1490                 'Lorde'     False  6FE9EXi8TYg09hR4xv5PWJ           0
# 1491         'Billie Eilish'     False  04sN26COy28wTXYj3dMoiZ          81
# 1492                 'Lorde'      True  1Dp7JGFNjvg8Nk0CtMCcnr          61
#
#       danceability  energy  key  loudness  mode  speechiness  ...          3  \
# 0            0.625  0.5680   11    -5.663     1       0.0324  ...  11.539323
# 1            0.584  0.4350   10   -11.736     0       0.0263  ...  18.214885
# 2            0.613  0.2890    8   -16.529     1       0.0305  ... -12.316468
# 3            0.365  0.3380    2   -13.406     1       0.0322  ...   2.044856
# 4            0.369  0.4670    5    -9.018     1       0.0274  ... -16.650313
# ...            ...     ...  ...       ...   ...          ...  ...        ...
# 1488         0.399  0.0969    6   -12.578     1       0.0509  ...   5.840797
# 1489         0.325  0.2710    7    -8.069     1       0.0418  ...  20.611754
# 1490         0.709  0.4590    5   -11.193     1       0.0654  ... -33.694737
# 1491         0.614  0.3180    7   -12.695     1       0.0478  ... -38.775284
# 1492         0.487  0.4450    1   -10.959     0       0.1130  ... -37.462178
#
#               4          5          6          7         8          9  \
# 0    -12.510097  23.383751 -16.174316   8.328809 -2.556505  -4.282422
# 1     -0.140513  24.040165 -24.511405  -3.840630 -6.885928  -2.012070
# 2    -12.847976  25.861839 -19.737157 -10.335721 -1.827133  -7.192570
# 3     -5.262738  31.014177 -18.898640 -13.315408 -2.899277  -7.657300
# 4    -22.373093  -1.733394 -29.764263   7.681281 -1.659771  -2.585452
# ...         ...        ...        ...        ...       ...        ...
# 1488 -22.330447  25.515002 -17.792400 -15.280099  1.405760  -9.261899
# 1489  -9.098635  29.450032 -13.189979 -17.050438 -2.646305 -14.314003
# 1490 -19.618376  30.164256 -24.133622 -19.055563 -6.317596  -6.653428
# 1491 -26.824530  42.881618 -28.542628 -12.061354 -0.955191  -2.552814
# 1492 -12.856534  14.994031 -25.034692  -2.974385  6.429797  -1.796132
#
#             10         11        12
# 0    -3.378086 -10.891944  2.584110
# 1    -1.377134  -7.607562  1.503317
# 2    -1.878703  -7.335082 -1.149978
# 3    -0.368305  -6.512232 -6.191590
# 4    -2.547789  -8.395570 -1.803018
# ...        ...        ...       ...
# 1488 -9.622248  -5.609669  2.967544
# 1489 -4.656721 -10.477538 -4.439217
# 1490 -2.188997  -8.915563 -1.431539
# 1491 -1.145596  -9.702547  3.082146
# 1492  0.191998 -12.925284 -6.119865
#
# [1493 rows x 29 columns]

# %% [markdown]
# Lastly, I changed the indices to be the track name because each observation is a songs.

# %%
df_tracks.set_index(indices, inplace=True)
df_tracks
# Out:
#                                            artists  explicit  \
# track.name
# You                                  'Miley Cyrus'     False
# Easy (LIke Sunday Morning)       'Charles Givings'     False
# Baby I'm-a Want You                        'Bread'     False
# Everything I Own                           'Bread'     False
# Apocalypse                  'Cigarettes After Sex'     False
# ...                                            ...       ...
# Godspeed                             'Frank Ocean'     False
# Writer In The Dark                         'Lorde'     False
# Mood Ring                                  'Lorde'     False
# Bored                              'Billie Eilish'     False
# Hard Feelings/Loveless                     'Lorde'      True
#
#                                                 id  popularity  danceability  \
# track.name
# You                         6FAsJDkg4y5JSWP9ZMKlDj          77         0.625
# Easy (LIke Sunday Morning)  5lnLxpRxCDlqedyWgkBLOh          47         0.584
# Baby I'm-a Want You         7IX2e7pEShera9T1QIMvi7          64         0.613
# Everything I Own            52VIdyKqp1pJRSyUQaxKUA          70         0.365
# Apocalypse                  3AVrVz5rK8Hrqo9YGiVGN5          81         0.369
# ...                                            ...         ...           ...
# Godspeed                    34xTFwjPQ1dC6uJmleno7x          72         0.399
# Writer In The Dark          193Dm5SqYy3hTSbuzxbwKc          65         0.325
# Mood Ring                   6FE9EXi8TYg09hR4xv5PWJ           0         0.709
# Bored                       04sN26COy28wTXYj3dMoiZ          81         0.614
# Hard Feelings/Loveless      1Dp7JGFNjvg8Nk0CtMCcnr          61         0.487
#
#                             energy  key  loudness  mode  speechiness  ...  \
# track.name                                                            ...
# You                         0.5680   11    -5.663     1       0.0324  ...
# Easy (LIke Sunday Morning)  0.4350   10   -11.736     0       0.0263  ...
# Baby I'm-a Want You         0.2890    8   -16.529     1       0.0305  ...
# Everything I Own            0.3380    2   -13.406     1       0.0322  ...
# Apocalypse                  0.4670    5    -9.018     1       0.0274  ...
# ...                            ...  ...       ...   ...          ...  ...
# Godspeed                    0.0969    6   -12.578     1       0.0509  ...
# Writer In The Dark          0.2710    7    -8.069     1       0.0418  ...
# Mood Ring                   0.4590    5   -11.193     1       0.0654  ...
# Bored                       0.3180    7   -12.695     1       0.0478  ...
# Hard Feelings/Loveless      0.4450    1   -10.959     0       0.1130  ...
#
#                                     3          4          5          6  \
# track.name
# You                         11.539323 -12.510097  23.383751 -16.174316
# Easy (LIke Sunday Morning)  18.214885  -0.140513  24.040165 -24.511405
# Baby I'm-a Want You        -12.316468 -12.847976  25.861839 -19.737157
# Everything I Own             2.044856  -5.262738  31.014177 -18.898640
# Apocalypse                 -16.650313 -22.373093  -1.733394 -29.764263
# ...                               ...        ...        ...        ...
# Godspeed                     5.840797 -22.330447  25.515002 -17.792400
# Writer In The Dark          20.611754  -9.098635  29.450032 -13.189979
# Mood Ring                  -33.694737 -19.618376  30.164256 -24.133622
# Bored                      -38.775284 -26.824530  42.881618 -28.542628
# Hard Feelings/Loveless     -37.462178 -12.856534  14.994031 -25.034692
#
#                                     7         8          9        10  \
# track.name
# You                          8.328809 -2.556505  -4.282422 -3.378086
# Easy (LIke Sunday Morning)  -3.840630 -6.885928  -2.012070 -1.377134
# Baby I'm-a Want You        -10.335721 -1.827133  -7.192570 -1.878703
# Everything I Own           -13.315408 -2.899277  -7.657300 -0.368305
# Apocalypse                   7.681281 -1.659771  -2.585452 -2.547789
# ...                               ...       ...        ...       ...
# Godspeed                   -15.280099  1.405760  -9.261899 -9.622248
# Writer In The Dark         -17.050438 -2.646305 -14.314003 -4.656721
# Mood Ring                  -19.055563 -6.317596  -6.653428 -2.188997
# Bored                      -12.061354 -0.955191  -2.552814 -1.145596
# Hard Feelings/Loveless      -2.974385  6.429797  -1.796132  0.191998
#
#                                    11        12
# track.name
# You                        -10.891944  2.584110
# Easy (LIke Sunday Morning)  -7.607562  1.503317
# Baby I'm-a Want You         -7.335082 -1.149978
# Everything I Own            -6.512232 -6.191590
# Apocalypse                  -8.395570 -1.803018
# ...                               ...       ...
# Godspeed                    -5.609669  2.967544
# Writer In The Dark         -10.477538 -4.439217
# Mood Ring                   -8.915563 -1.431539
# Bored                       -9.702547  3.082146
# Hard Feelings/Loveless     -12.925284 -6.119865
#
# [1493 rows x 29 columns]

# %% [markdown]
# Finally, I downloaded the data as a csv, so I could explore it in another colab!

# %%
from google.colab import files

df_tracks.to_csv('tracks.csv', index=True)
files.download('tracks.csv')
